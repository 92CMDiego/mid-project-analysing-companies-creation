# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Main/main.csv')

# %%
df.head()
# Out:
#          id ISO_code_alpha3      Country  Adult population  Year  \
# 0  AFG-2009             AFG  Afghanistan          14039528  2009
# 1  AFG-2010             AFG  Afghanistan          14444996  2010
# 2  AFG-2011             AFG  Afghanistan          15041824  2011
# 3  AFG-2012             AFG  Afghanistan          15743958  2012
# 4  AFG-2013             AFG  Afghanistan          16519812  2013
#
#    Number of new Limited Liability Companies  New business density rate  \
# 0                                       3653                       0.26
# 1                                       4759                       0.33
# 2                                       3745                       0.25
# 3                                       3557                       0.23
# 4                                       3191                       0.19
#
#    Economic freedom index  Property Rights  Judicial Effectiveness  ...  \
# ...

# %% [markdown]
# Ordering by New business density rate.

# %%
df_nbd = df.groupby('Country').agg({'New business density rate': 'mean'})

# %%
df_nbd.sort_values(by='New business density rate', ascending=False).head(50)
# Out:
#                      New business density rate
# Country
# Isle of Man                          51.675455
# Hong Kong                            25.074000
# Cyprus                               20.797333
# New Zealand                          17.962667
# Estonia                              16.653333
# Luxembourg                           14.114000
# Dominica                             13.400833
# Malta                                13.248000
# United Kingdom                       12.865333
# Australia                            12.667333
# Cook Islands                         12.579091
# Botswana                             12.375333
# Iceland                              10.920000
# Chile                                 9.327500
# Latvia                                8.573333
# South Africa                          8.501538
# Mauritius                             8.406000
# Panama                                8.200000
# Singapore                             7.912667
# ...

# %% [markdown]
# Ordering by Economic Freedom index overall score.

# %%
df_os = df.groupby('Country').agg({'Economic freedom index': 'mean'})

# %%
df_os.sort_values(by='Economic freedom index', ascending=False).head(50)
# Out:
#                                   Economic freedom index
# Country
# Hong Kong                                      89.622000
# Singapore                                      88.072667
# New Zealand                                    82.354667
# Australia                                      81.718000
# Switzerland                                    80.652143
# Ireland                                        79.380000
# Canada                                         78.100000
# Chile                                          77.225000
# United Kingdom                                 77.220667
# Denmark                                        76.882308
# Estonia                                        76.511333
# Netherlands                                    76.080000
# Luxembourg                                     74.909000
# Mauritius                                      74.355333
# Iceland                                        74.114667
# ...

# %% [markdown]
# Government integrity.

# %%
df[df['Government Integrity']==df['Government Integrity'].max()]
# Out:
#            id ISO_code_alpha3  Country  Adult population  Year  \
# 523  FIN-2006             FIN  Finland           3507533  2006
# 703  ISL-2007             ISL  Iceland            207445  2007
#
#      Number of new Limited Liability Companies  New business density rate  \
# 523                                      10247                       2.92
# 703                                       3648                      17.59
#
#      Economic freedom index  Property Rights  Judicial Effectiveness  ...  \
# 523                    72.9             90.0                     NaN  ...
# 703                    76.0             90.0                     NaN  ...
#
#      Investment Freedom  Financial Freedom  Rule of Law  Government Size  \
# 523                70.0               70.0          NaN              NaN
# 703                60.0               70.0          NaN              NaN
#
#      Regulatory Efficiency  Open Markets  Corporate tax (Tax Foundation)  \
# ...
