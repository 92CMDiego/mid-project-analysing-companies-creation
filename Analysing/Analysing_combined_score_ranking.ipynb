# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output_table_combined_score_ranking.csv')

# %%
df.sort_values(by='combined_score', ascending=False).head(10)
# Out:
#    ISO_code_alpha3         Country  New business density rate mean  \
# 36             HKG       Hong Kong                       25.074000
# 75             NZL     New Zealand                       17.962667
# 19             CYP          Cyprus                       20.797333
# 27             EST         Estonia                       16.653333
# 4              AUS       Australia                       12.667333
# 59             LUX      Luxembourg                       14.114000
# 88             SGP       Singapore                        7.912667
# 31             GBR  United Kingdom                       12.865333
# 42             ISL         Iceland                       10.920000
# 14             BWA        Botswana                       12.375333
#
#     Economic freedom index mean  new_business_density_mean_scaled  \
# 36                    89.622000                          1.000000
# 75                    82.354667                          0.716228
# ...

# %%
main = pd.read_csv('../Main/main.csv')

# %%
count = main.groupby('Year')['ISO_code_alpha3'].nunique()
count
# Out:
# Year
# 2006    109
# 2007    111
# 2008    118
# 2009    125
# 2010    125
# 2011    129
# 2012    131
# 2013    137
# 2014    141
# 2015    144
# 2016    149
# 2017    145
# 2018    147
# 2019    120
# 2020    120
# Name: ISO_code_alpha3, dtype: int64

# %% [markdown]
# New Zealand.

# %%
main[main['ISO_code_alpha3']=='NZL']
# Out:
#             id ISO_code_alpha3      Country  Adult population  Year  \
# 1200  NZL-2006             NZL  New Zealand           2781336  2006
# 1201  NZL-2007             NZL  New Zealand           2809736  2007
# 1202  NZL-2008             NZL  New Zealand           2834758  2008
# 1203  NZL-2009             NZL  New Zealand           2862340  2009
# 1204  NZL-2010             NZL  New Zealand           2891030  2010
# 1205  NZL-2011             NZL  New Zealand           2902789  2011
# 1206  NZL-2012             NZL  New Zealand           2909454  2012
# 1207  NZL-2013             NZL  New Zealand           2922995  2013
# 1208  NZL-2014             NZL  New Zealand           2962680  2014
# 1209  NZL-2015             NZL  New Zealand           3013718  2015
# 1210  NZL-2016             NZL  New Zealand           3073135  2016
# 1211  NZL-2017             NZL  New Zealand           3126644  2017
# 1212  NZL-2018             NZL  New Zealand           3170401  2018
# ...

# %%
main[main['ISO_code_alpha3']=='NZL'].describe()
# Out:
#        Adult population         Year  \
# count      1.500000e+01    15.000000
# mean       2.982255e+06  2013.000000
# std        1.526711e+05     4.472136
# min        2.781336e+06  2006.000000
# 25%        2.876685e+06  2009.500000
# 50%        2.922995e+06  2013.000000
# 75%        3.099890e+06  2016.500000
# max        3.264172e+06  2020.000000
#
#        Number of new Limited Liability Companies  New business density rate  \
# count                                  15.000000                  15.000000
# mean                                53444.666667                  17.962667
# std                                  8315.686843                   3.053963
# min                                 42172.000000                  14.530000
# 25%                                 46867.500000                  16.065000
# 50%                                 53098.000000                  17.370000
# 75%                                 58023.500000                  18.680000
# ...

# %%
main[main['ISO_code_alpha3']=='NZL']['median_age'].mean()
# Out:
# 35.973333333333336

# %% [markdown]
# Estonia.

# %%
main[main['ISO_code_alpha3']=='EST'].describe()
# Out:
#        Adult population         Year  \
# count         15.000000    15.000000
# mean      874601.600000  2013.000000
# std        26871.943387     4.472136
# min       840278.000000  2006.000000
# 25%       851015.000000  2009.500000
# 50%       870282.000000  2013.000000
# 75%       899474.000000  2016.500000
# max       915809.000000  2020.000000
#
#        Number of new Limited Liability Companies  New business density rate  \
# count                                  15.000000                  15.000000
# mean                                14447.666667                  16.653333
# std                                  4085.639969                   5.156592
# min                                  8183.000000                   9.070000
# 25%                                 11834.500000                  12.960000
# 50%                                 13867.000000                  16.090000
# 75%                                 17516.500000                  20.585000
# ...

# %%
main[main['ISO_code_alpha3']=='EST']
# Out:
#            id ISO_code_alpha3  Country  Adult population  Year  \
# 488  EST-2006             EST  Estonia            915809  2006
# 489  EST-2007             EST  Estonia            910562  2007
# 490  EST-2008             EST  Estonia            906562  2008
# 491  EST-2009             EST  Estonia            902296  2009
# 492  EST-2010             EST  Estonia            896652  2010
# 493  EST-2011             EST  Estonia            888349  2011
# 494  EST-2012             EST  Estonia            879415  2012
# 495  EST-2013             EST  Estonia            870282  2013
# 496  EST-2014             EST  Estonia            861690  2014
# 497  EST-2015             EST  Estonia            855639  2015
# 498  EST-2016             EST  Estonia            852779  2016
# 499  EST-2017             EST  Estonia            849251  2017
# 500  EST-2018             EST  Estonia            846284  2018
# 501  EST-2019             EST  Estonia            843176  2019
# ...

# %%
main[main['ISO_code_alpha3']=='EST']['median_age'].mean()
# Out:
# 39.99333333333333
