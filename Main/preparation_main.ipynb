# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Datasets/Birth of enterprises/prepared_ worldbank_new_firms_historical_data_1.csv')

# %%
df
# Out:
#             id ISO_code_alpha3      Country  Adult population  Year  \
# 0     AFG-2009             AFG  Afghanistan          14039528  2009
# 1     AFG-2010             AFG  Afghanistan          14444996  2010
# 2     AFG-2011             AFG  Afghanistan          15041824  2011
# 3     AFG-2012             AFG  Afghanistan          15743958  2012
# 4     AFG-2013             AFG  Afghanistan          16519812  2013
# ...        ...             ...          ...               ...   ...
# 1946  ZWE-2016             ZWE     Zimbabwe           7642765  2016
# 1947  ZWE-2017             ZWE     Zimbabwe           7759792  2017
# 1948  ZWE-2018             ZWE     Zimbabwe           7892169  2018
# 1949  ZWE-2019             ZWE     Zimbabwe           8034692  2019
# 1950  ZWE-2020             ZWE     Zimbabwe           8185716  2020
#
#       Number of new Limited Liability Companies  New business density rate
# 0                                          3653                       0.26
# ...

# %%
df_efi = pd.read_csv('../Datasets/Economic freedom index/prepared_economic_freedom_scores_1995_2023.csv')

# %%
df_efi
# Out:
#             id     Country ISO_code_alpha3 ISO_code_alpha2  Index Year  \
# 0     ALB-2023     Albania             ALB              AL        2023
# 1     DZA-2023     Algeria             DZA              DZ        2023
# 2     AGO-2023      Angola             AGO              AO        2023
# 3     ARG-2023   Argentina             ARG              AR        2023
# 4     ARM-2023     Armenia             ARM              AM        2023
# ...        ...         ...             ...             ...         ...
# 4754  VEN-1995  Venezuela              VEN              VE        1995
# 4755  VNM-1995     Vietnam             VNM              VN        1995
# 4756  YEM-1995       Yemen             YEM              YE        1995
# 4757  ZMB-1995      Zambia             ZMB              ZM        1995
# 4758  ZWE-1995    Zimbabwe             ZWE              ZW        1995
#
#       Overall Score  Property Rights  Judicial Effectiveness  \
# ...

# %%
cols = df_efi.drop('Country', axis=1).drop('ISO_code_alpha3', axis=1).drop('ISO_code_alpha2', axis=1).drop('Index Year', axis=1)
df = df.merge(cols, how='left', left_on='id', right_on='id')

# %%
df
# Out:
#             id ISO_code_alpha3      Country  Adult population  Year  \
# 0     AFG-2009             AFG  Afghanistan          14039528  2009
# 1     AFG-2010             AFG  Afghanistan          14444996  2010
# 2     AFG-2011             AFG  Afghanistan          15041824  2011
# 3     AFG-2012             AFG  Afghanistan          15743958  2012
# 4     AFG-2013             AFG  Afghanistan          16519812  2013
# ...        ...             ...          ...               ...   ...
# 1946  ZWE-2016             ZWE     Zimbabwe           7642765  2016
# 1947  ZWE-2017             ZWE     Zimbabwe           7759792  2017
# 1948  ZWE-2018             ZWE     Zimbabwe           7892169  2018
# 1949  ZWE-2019             ZWE     Zimbabwe           8034692  2019
# 1950  ZWE-2020             ZWE     Zimbabwe           8185716  2020
#
#       Number of new Limited Liability Companies  New business density rate  \
# ...

# %%
df.isna().sum()
# Out:
# id                                              0
# ISO_code_alpha3                                 0
# Country                                         0
# Adult population                                0
# Year                                            0
# Number of new Limited Liability Companies       0
# New business density rate                       0
# Overall Score                                 150
# Property Rights                               150
# Judicial Effectiveness                       1437
# Government Integrity                          150
# Tax Burden                                    150
# Government Spending                           150
# Fiscal Health                                1437
# Business Freedom                              150
# Labor Freedom                                 150
# Monetary Freedom                              150
# Trade Freedom                                 150
# Investment Freedom                            150
# ...

# %%
len(df)
# Out:
# 1951

# %%
df_tf_ct = pd.read_csv('../Datasets/Coporate tax/TaxFoundation/prepared_taxfoundation_1980_2022_corporate_tax_rates_1.csv')

# %%
df_tf_ct.head()
# Out:
#          id iso_2 iso_3 continent        country  Year  \
# 0  ABW-1980    AW   ABW        NO          Aruba  1980
# 1  AFG-1980    AF   AFG        AS    Afghanistan  1980
# 2  AGO-1980    AO   AGO        AF         Angola  1980
# 3  AIA-1980    AI   AIA        NO       Anguilla  1980
# 4  ALA-1980    AX   ALA        EU  Aland Islands  1980
#
#    Corporate tax (Tax Foundation)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
cols = df_tf_ct.drop('iso_2', axis=1).drop('iso_3', axis=1).drop('continent', axis=1).drop('country', axis=1).drop('Year', axis=1)
df = df.merge(cols, how='left', left_on='id', right_on='id')

# %%
df.head()
# Out:
#          id ISO_code_alpha3      Country  Adult population  Year  \
# 0  AFG-2009             AFG  Afghanistan          14039528  2009
# 1  AFG-2010             AFG  Afghanistan          14444996  2010
# 2  AFG-2011             AFG  Afghanistan          15041824  2011
# 3  AFG-2012             AFG  Afghanistan          15743958  2012
# 4  AFG-2013             AFG  Afghanistan          16519812  2013
#
#    Number of new Limited Liability Companies  New business density rate  \
# 0                                       3653                       0.26
# 1                                       4759                       0.33
# 2                                       3745                       0.25
# 3                                       3557                       0.23
# 4                                       3191                       0.19
#
#    Overall Score  Property Rights  Judicial Effectiveness  ...  Labor Freedom  \
# ...

# %%
df.isna().sum()
# Out:
# id                                              0
# ISO_code_alpha3                                 0
# Country                                         0
# Adult population                                0
# Year                                            0
# Number of new Limited Liability Companies       0
# New business density rate                       0
# Overall Score                                 150
# Property Rights                               150
# Judicial Effectiveness                       1437
# Government Integrity                          150
# Tax Burden                                    150
# Government Spending                           150
# Fiscal Health                                1437
# Business Freedom                              150
# Labor Freedom                                 150
# Monetary Freedom                              150
# Trade Freedom                                 150
# Investment Freedom                            150
# ...

# %%
df_oecd_ct = pd.read_csv('../Datasets/Coporate tax/OECD/prepared_oecd_central_government_corporate_tax_2001_2022.csv')

# %%
df_oecd_ct.head()
# Out:
#          id ISO_code_alpha3          Country  Year  Corporate tax (OECD)
# 0  SVK-2001             SVK  Slovak Republic  2001                  29.0
# 1  SVK-2002             SVK  Slovak Republic  2002                  25.0
# 2  SVK-2003             SVK  Slovak Republic  2003                  25.0
# 3  SVK-2004             SVK  Slovak Republic  2004                  19.0
# 4  SVK-2005             SVK  Slovak Republic  2005                  19.0

# %%
cols = df_oecd_ct.drop('ISO_code_alpha3', axis=1).drop('Country', axis=1).drop('Year', axis=1)
df = df.merge(cols, how='left', left_on='id', right_on='id')

# %%
df.head()
# Out:
#          id ISO_code_alpha3      Country  Adult population  Year  \
# 0  AFG-2009             AFG  Afghanistan          14039528  2009
# 1  AFG-2010             AFG  Afghanistan          14444996  2010
# 2  AFG-2011             AFG  Afghanistan          15041824  2011
# 3  AFG-2012             AFG  Afghanistan          15743958  2012
# 4  AFG-2013             AFG  Afghanistan          16519812  2013
#
#    Number of new Limited Liability Companies  New business density rate  \
# 0                                       3653                       0.26
# 1                                       4759                       0.33
# 2                                       3745                       0.25
# 3                                       3557                       0.23
# 4                                       3191                       0.19
#
#    Overall Score  Property Rights  Judicial Effectiveness  ...  \
# 0            NaN              NaN                     NaN  ...
# ...

# %%
df.isna().sum()
# Out:
# id                                              0
# ISO_code_alpha3                                 0
# Country                                         0
# Adult population                                0
# Year                                            0
# Number of new Limited Liability Companies       0
# New business density rate                       0
# Overall Score                                 150
# Property Rights                               150
# Judicial Effectiveness                       1437
# Government Integrity                          150
# Tax Burden                                    150
# Government Spending                           150
# Fiscal Health                                1437
# Business Freedom                              150
# Labor Freedom                                 150
# Monetary Freedom                              150
# Trade Freedom                                 150
# Investment Freedom                            150
# ...

# %%
df_inn = pd.read_csv('../Datasets/Global innovation index/prepared_gii_2013_2020.csv')
df_ma = pd.read_csv('../Datasets/Population median age/prepared_owid_median_age_estimates.csv')

# %%
df_inn.head()
# Out:
#          id ISO_code_alpha3      Country  Year  Global Innovation Index
# 0  ABW-2013             ABW        Aruba  2013                      NaN
# 1  AFG-2013             AFG  Afghanistan  2013                      NaN
# 2  AGO-2013             AGO       Angola  2013                     23.5
# 3  ALB-2013             ALB      Albania  2013                     30.9
# 4  AND-2013             AND      Andorra  2013                      NaN

# %%
cols = df_inn.drop('ISO_code_alpha3', axis=1).drop('Country', axis=1).drop('Year', axis=1)
df = df.merge(cols, how='left', left_on='id', right_on='id')

# %%
df_ma.head()
# Out:
#          id ISO_code_alpha3      Country  Year  median_age
# 0  AFG-1950             AFG  Afghanistan  1950        18.4
# 1  AFG-1951             AFG  Afghanistan  1951        18.4
# 2  AFG-1952             AFG  Afghanistan  1952        18.4
# 3  AFG-1953             AFG  Afghanistan  1953        18.3
# 4  AFG-1954             AFG  Afghanistan  1954        18.3

# %%
cols = df_ma.drop('ISO_code_alpha3', axis=1).drop('Country', axis=1).drop('Year', axis=1)
df = df.merge(cols, how='left', left_on='id', right_on='id')

# %%
df.head()
# Out:
#          id ISO_code_alpha3      Country  Adult population  Year  \
# 0  AFG-2009             AFG  Afghanistan          14039528  2009
# 1  AFG-2010             AFG  Afghanistan          14444996  2010
# 2  AFG-2011             AFG  Afghanistan          15041824  2011
# 3  AFG-2012             AFG  Afghanistan          15743958  2012
# 4  AFG-2013             AFG  Afghanistan          16519812  2013
#
#    Number of new Limited Liability Companies  New business density rate  \
# 0                                       3653                       0.26
# 1                                       4759                       0.33
# 2                                       3745                       0.25
# 3                                       3557                       0.23
# 4                                       3191                       0.19
#
#    Overall Score  Property Rights  Judicial Effectiveness  ...  \
# 0            NaN              NaN                     NaN  ...
# ...

# %%
df = df.rename(columns={'Overall Score': 'Economic freedom index'})

# %%
df.head()
# Out:
#          id ISO_code_alpha3      Country  Adult population  Year  \
# 0  AFG-2009             AFG  Afghanistan          14039528  2009
# 1  AFG-2010             AFG  Afghanistan          14444996  2010
# 2  AFG-2011             AFG  Afghanistan          15041824  2011
# 3  AFG-2012             AFG  Afghanistan          15743958  2012
# 4  AFG-2013             AFG  Afghanistan          16519812  2013
#
#    Number of new Limited Liability Companies  New business density rate  \
# 0                                       3653                       0.26
# 1                                       4759                       0.33
# 2                                       3745                       0.25
# 3                                       3557                       0.23
# 4                                       3191                       0.19
#
#    Economic freedom index  Property Rights  Judicial Effectiveness  ...  \
# ...

# %%
df.isna().sum()
# Out:
# id                                              0
# ISO_code_alpha3                                 0
# Country                                         0
# Adult population                                0
# Year                                            0
# Number of new Limited Liability Companies       0
# New business density rate                       0
# Economic freedom index                        150
# Property Rights                               150
# Judicial Effectiveness                       1437
# Government Integrity                          150
# Tax Burden                                    150
# Government Spending                           150
# Fiscal Health                                1437
# Business Freedom                              150
# Labor Freedom                                 150
# Monetary Freedom                              150
# Trade Freedom                                 150
# Investment Freedom                            150
# ...

# %%
df.to_csv('main.csv', index=False)
